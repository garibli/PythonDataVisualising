# %%
# Havvanaz Şimşek
# B211818371
# Veri Bilimi Dersi
# Ekonometri

# %%
# Kütüpaneleri dahil ediniz
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#datasete erişme
df = pd.read_csv('dataset.csv', encoding='latin1')

# %%
#Verisetinin ilk satırlarını al ve göster
print("Veri Başlığı")
print(df.head())
# Out:
# Veri Başlığı
#    Year  District Code District Name  Neighborhood Code  Age  Immigrants  \
# 0  2017              1  Ciutat Vella                  1  0-4         154
# 1  2017              1  Ciutat Vella                  2  0-4          58
# 2  2017              1  Ciutat Vella                  3  0-4          38
# 3  2017              1  Ciutat Vella                  4  0-4          56
# 4  2017              2      Eixample                  5  0-4          79
#
#    Emigrants
# 0        108
# 1         33
# 2         37
# 3         55
# 4         60

# %%
#değer girilmeyen haneleri aşkarla
print("\nMissing values in each column:")
print(df.isnull().sum())
# Out:
# Missing values in each column:
# Year                 0
# District Code        0
# District Name        0
# Neighborhood Code    0
# Age                  0
# Immigrants           0
# Emigrants            0
# dtype: int64

# %%
#datasetin istatistiklerini göster 
print("\nSummary statistics:")
print(df.describe())
# Out:
# Summary statistics:
#               Year  District Code  Neighborhood Code   Immigrants    Emigrants
# count  4662.000000    4662.000000        4662.000000  4662.000000  4662.000000
# mean   2016.000000       7.500000          37.837838    58.232733    33.684041
# std       0.816584      11.062746          22.121233   108.970536    45.925365
# min    2015.000000       1.000000           1.000000     0.000000     0.000000
# 25%    2015.000000       4.000000          19.000000     5.000000     6.000000
# 50%    2016.000000       7.000000          37.500000    21.000000    18.000000
# 75%    2017.000000       8.000000          56.000000    64.000000    42.000000
# max    2017.000000      99.000000          99.000000  1393.000000   451.000000

# %%
# Plotting with Seaborn
plt.figure(figsize=(12, 6))
sns.barplot(data=grouped_df, x='District Name', y='Immigrants', hue='Age')
plt.title('Total Immigrants by District')
plt.ylabel('Number of Immigrants')
plt.xlabel('District Name')
plt.legend(title='Age Group')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=grouped_df, x='District Name', y='Emigrants', hue='Age')
plt.title('Total Emigrants by District')
plt.ylabel('Number of Emigrants')
plt.xlabel('District Name')
plt.legend(title='Age Group')
plt.show()

# %%
# Combined plot for Immigrants and Emigrants
grouped_df_melted = grouped_df.melt(id_vars=['District Name', 'Age'], value_vars=['Immigrants', 'Emigrants'], 
                                    var_name='Migration Type', value_name='Count')
print(grouped_df_melted)
# Out:
#             District Name     Age Migration Type  Count
# 0            Ciutat Vella     0-4     Immigrants    982
# 1            Ciutat Vella  14-Oct     Immigrants    581
# 2            Ciutat Vella   15-19     Immigrants   1577
# 3            Ciutat Vella   20-24     Immigrants   5746
# 4            Ciutat Vella   25-29     Immigrants   9294
# ..                    ...     ...            ...    ...
# 457  SarriÃ -Sant Gervasi   85-89      Emigrants    173
# 458  SarriÃ -Sant Gervasi   9-May      Emigrants    557
# 459  SarriÃ -Sant Gervasi   90-94      Emigrants    117
# 460  SarriÃ -Sant Gervasi   95-99      Emigrants     32
# 461  SarriÃ -Sant Gervasi   >=100      Emigrants      4
#
# [462 rows x 4 columns]

# %%
plt.figure(figsize=(14, 7))
sns.barplot(data=grouped_df_melted, x='District Name', y='Count', hue='Migration Type') #seaborn kütüpanesi
plt.title('Total Immigrants and Emigrants by District')
plt.ylabel('Count')
plt.xlabel('District Name')
plt.legend(title='Migration Type')
plt.show()
